# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.3.0.36-cp35-cp35m-manylinux2014_x86_64.whl (43.7 MB)
# Requirement already satisfied: numpy>=1.11.1 in ./anaconda3/lib/python3.5/site-packages (from opencv-python) (1.15.2)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.3.0.36

# %%
# !sudo apt-get install libsm6 libxrender1 libfontconfig1

# %%
import pandas as pd
import numpy as np
import cv2

import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# /home/srijonsarkar41/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/srijonsarkar41/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
! git clone https://github.com/srijonsarkar/Movie-Genre-Prediction
# Out:
# fatal: destination path 'Movie-Genre-Prediction' already exists and is not an empty directory.

# %%
df = pd.read_csv('Movie-Genre-Prediction/movies_metadata_modded.csv')
df.head(10)
# Out:
#                                 genres      id    imdb_id original_language  \
# 0  [{'id': 99, 'name': 'Documentary'}]  315946  tt3155794                xx
# 1  [{'id': 99, 'name': 'Documentary'}]  194079  tt2221420                en
# 2  [{'id': 99, 'name': 'Documentary'}]  426903  tt5459794                en
# 3  [{'id': 99, 'name': 'Documentary'}]  159897  tt2075247                xx
# 4  [{'id': 99, 'name': 'Documentary'}]   96882  tt1758563                xx
# 5  [{'id': 99, 'name': 'Documentary'}]   16464  tt0343112                xx
# 6  [{'id': 99, 'name': 'Documentary'}]   33316  tt1202028                xx
# 7                                   []  386743  tt5285442                en
# 8       [{'id': 35, 'name': 'Comedy'}]   32571  tt0361921                en
# 9                                   []   33315  tt0416046                xx
#
#   release_date
# 0   1874-12-09
# 1   1878-06-14
# 2   1883-11-19
# 3   1887-08-18
# 4   1888-01-01
# 5   1888-10-15
# 6   1890-01-01
# 7   1890-03-09
# 8   1890-11-21
# 9   1890-11-21

# %%
# keeping only english movies in dataset
df = df[df.original_language=='en'].copy()
df.shape
# Out:
# (32111, 5)

# %%
# have to remove movies released before 1990s
df.release_date = df.release_date.astype('str')

df.release_date = df.release_date.apply(lambda x : x[:4])

# %%
df.release_date = df.release_date.astype('int16')
df2 = df[df.release_date >= 1990].copy()
df2.head(20)
# Out:
#                                                   genres      id    imdb_id  \
# 15648  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   44281  tt0090665
# 15649  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   41927  tt0100822
# 15650  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...    8996  tt0099776
# 15651  [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...   57476  tt0100670
# 15652                [{'id': 99, 'name': 'Documentary'}]   37447  tt0099121
# 15653  [{'id': 10749, 'name': 'Romance'}, {'id': 53, ...   41925  tt0099292
# 15655                     [{'id': 27, 'name': 'Horror'}]   67515  tt0100079
# 15658                   [{'id': 10402, 'name': 'Music'}]   44257  tt0099844
# 15659                                                 []   40959  tt0243199
# 15661  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...   13293  tt0099260
# 15663  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   41810  tt0099017
# 15664                     [{'id': 35, 'name': 'Comedy'}]   21811  tt0102940
# 15665  [{'id': 16, 'name': 'Animation'}, {'id': 10751...   13759  tt0100281
# 15666                      [{'id': 18, 'name': 'Drama'}]   91138  tt0099796
# 15667           [{'id': 878, 'name': 'Science Fiction'}]   30647  tt0098962
# 15669  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...   31942  tt0100148
# 15670                                                 []  251489  tt0099463
# 15672  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    5086  tt0100448
# 15675  [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...   31647  tt0102569
# 15681  [{'id': 878, 'name': 'Science Fiction'}, {'id'...   24862  tt0099313
#
#       original_language  release_date
# 15648                en          1990
# 15649                en          1990
# 15650                en          1990
# 15651                en          1990
# 15652                en          1990
# 15653                en          1990
# 15655                en          1990
# 15658                en          1990
# 15659                en          1990
# 15661                en          1990
# 15663                en          1990
# 15664                en          1990
# 15665                en          1990
# 15666                en          1990
# 15667                en          1990
# 15669                en          1990
# 15670                en          1990
# 15672                en          1990
# 15675                en          1990
# 15681                en          1990

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (32101, 5)

# %%
df2.head(10)
# Out:
#                                                   genres     id    imdb_id  \
# 15648  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  44281  tt0090665
# 15649  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  41927  tt0100822
# 15650  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...   8996  tt0099776
# 15651  [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...  57476  tt0100670
# 15652                [{'id': 99, 'name': 'Documentary'}]  37447  tt0099121
# 15653  [{'id': 10749, 'name': 'Romance'}, {'id': 53, ...  41925  tt0099292
# 15655                     [{'id': 27, 'name': 'Horror'}]  67515  tt0100079
# 15658                   [{'id': 10402, 'name': 'Music'}]  44257  tt0099844
# 15659                                                 []  40959  tt0243199
# 15661  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  13293  tt0099260
#
#       original_language  release_date
# 15648                en          1990
# 15649                en          1990
# 15650                en          1990
# 15651                en          1990
# 15652                en          1990
# 15653                en          1990
# 15655                en          1990
# 15658                en          1990
# 15659                en          1990
# 15661                en          1990

# %%
df2.reset_index(inplace=True)
df2.head()
# Out:
#    index                                             genres     id    imdb_id  \
# 0  15648  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  44281  tt0090665
# 1  15649  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  41927  tt0100822
# 2  15650  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...   8996  tt0099776
# 3  15651  [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...  57476  tt0100670
# 4  15652                [{'id': 99, 'name': 'Documentary'}]  37447  tt0099121
#
#   original_language  release_date
# 0                en          1990
# 1                en          1990
# 2                en          1990
# 3                en          1990
# 4                en          1990

# %%
df2.drop('index', axis=1, inplace=True)
df2.head()
# Out:
#                                               genres     id    imdb_id  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  44281  tt0090665
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  41927  tt0100822
# 2  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...   8996  tt0099776
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...  57476  tt0100670
# 4                [{'id': 99, 'name': 'Documentary'}]  37447  tt0099121
#
#   original_language  release_date
# 0                en          1990
# 1                en          1990
# 2                en          1990
# 3                en          1990
# 4                en          1990

# %%
# remove duplicate rows from df2

df2.drop_duplicates('imdb_id', inplace=True)
df2.shape
# Out:
# (20896, 5)

# %%
df2.reset_index(inplace=True)

# %%
df2.drop('index',axis=1,inplace=True)
df2.head()
# Out:
#                                               genres     id    imdb_id  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  44281  tt0090665
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  41927  tt0100822
# 2  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...   8996  tt0099776
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...  57476  tt0100670
# 4                [{'id': 99, 'name': 'Documentary'}]  37447  tt0099121
#
#   original_language  release_date
# 0                en          1990
# 1                en          1990
# 2                en          1990
# 3                en          1990
# 4                en          1990

# %%
# now we have only english movies released after 1990 in our dataset df2
# need to remove movies which don't have any genres specified

l=[]
for i in range(len(df2)):
    if len(eval(df2.iloc[i,0]))==0:
        l.append(i)
        
print(len(l))
# Out:
# 1050

# %%
# need to drop these 1050 rows

df2.drop(l, inplace=True)
df2.shape
# Out:
# (19846, 5)

# %%
df2.reset_index(inplace=True)
df2.drop('index',axis=1,inplace=True)
df2.head()
# Out:
#                                               genres     id    imdb_id  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  44281  tt0090665
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  41927  tt0100822
# 2  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...   8996  tt0099776
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...  57476  tt0100670
# 4                [{'id': 99, 'name': 'Documentary'}]  37447  tt0099121
#
#   original_language  release_date
# 0                en          1990
# 1                en          1990
# 2                en          1990
# 3                en          1990
# 4                en          1990

# %%
# shows how many movies in each genre

dict_g = {}
for i in range(len(df2)):
    genres = eval(df2.iloc[i,0])
    
    for genre in genres:
        if genre['name'] not in dict_g.keys():
            dict_g[str(genre['name'])] = 1
        else:
            dict_g[str(genre['name'])] += 1

# %%
dict_g
# Out:
# {'Action': 3050,
#  'Adventure': 1602,
#  'Animation': 918,
#  'Comedy': 6067,
#  'Crime': 1783,
#  'Documentary': 2969,
#  'Drama': 8280,
#  'Family': 1669,
#  'Fantasy': 1064,
#  'Foreign': 541,
#  'History': 526,
#  'Horror': 2458,
#  'Music': 718,
#  'Mystery': 1128,
#  'Romance': 2830,
#  'Science Fiction': 1627,
#  'TV Movie': 579,
#  'Thriller': 4316,
#  'War': 335,
#  'Western': 188}

# %%
plt.bar( dict_g.keys(), dict_g.values(), width=1)
plt.figure(figsize=(40,12))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-20e4b9651a64> in <module>()
# ----> 1 plt.bar( dict_g.keys(), dict_g.values(), width=1)
#       2 plt.figure(figsize=(40,12))
#
# /home/srijonsarkar41/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py in bar(left, height, width, bottom, hold, data, **kwargs)
#    2641     try:
#    2642         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2643                      **kwargs)
#    2644     finally:
#    2645         ax.hold(washold)
#
# /home/srijonsarkar41/anaconda3/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /home/srijonsarkar41/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_axes.py in bar(self, left, height, width, bottom, **kwargs)
#    2127                 edgecolor=e,
#    2128                 linewidth=lw,
# -> 2129                 label='_nolegend_'
#    2130                 )
#    2131             r.update(kwargs)
#
# /home/srijonsarkar41/anaconda3/lib/python3.5/site-packages/matplotlib/patches.py in __init__(self, xy, width, height, angle, **kwargs)
#     639         Patch.__init__(self, **kwargs)
#     640
# --> 641         self._x = float(xy[0])
#     642         self._y = float(xy[1])
#     643         self._width = float(width)
#
# ValueError: could not convert string to float: 'Romance'

# %%
df2.head(20)
# Out:
#                                                genres      id    imdb_id  \
# 0   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   44281  tt0090665
# 1   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   41927  tt0100822
# 2   [{'id': 36, 'name': 'History'}, {'id': 18, 'na...    8996  tt0099776
# 3   [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...   57476  tt0100670
# 4                 [{'id': 99, 'name': 'Documentary'}]   37447  tt0099121
# 5   [{'id': 10749, 'name': 'Romance'}, {'id': 53, ...   41925  tt0099292
# 6                      [{'id': 27, 'name': 'Horror'}]   67515  tt0100079
# 7                    [{'id': 10402, 'name': 'Music'}]   44257  tt0099844
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...   13293  tt0099260
# 9   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   41810  tt0099017
# 10                     [{'id': 35, 'name': 'Comedy'}]   21811  tt0102940
# 11  [{'id': 16, 'name': 'Animation'}, {'id': 10751...   13759  tt0100281
# 12                      [{'id': 18, 'name': 'Drama'}]   91138  tt0099796
# 13           [{'id': 878, 'name': 'Science Fiction'}]   30647  tt0098962
# 14  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...   31942  tt0100148
# 15  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    5086  tt0100448
# 16  [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...   31647  tt0102569
# 17  [{'id': 878, 'name': 'Science Fiction'}, {'id'...   24862  tt0099313
# 18  [{'id': 10749, 'name': 'Romance'}, {'id': 36, ...   87628  tt0099655
# 19  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...  162934  tt0094333
#
#    original_language  release_date
# 0                 en          1990
# 1                 en          1990
# 2                 en          1990
# 3                 en          1990
# 4                 en          1990
# 5                 en          1990
# 6                 en          1990
# 7                 en          1990
# 8                 en          1990
# 9                 en          1990
# 10                en          1990
# 11                en          1990
# 12                en          1990
# 13                en          1990
# 14                en          1990
# 15                en          1990
# 16                en          1990
# 17                en          1990
# 18                en          1990
# 19                en          1990

# %%
df2.shape
# Out:
# (19846, 5)

# %%
genres_dict = {     
     12: "Adventure",
     14: "Fantasy",
     16: "Animation",
     18: "Drama",
     27: "Horror", 
     28: "Action",
     35: "Comedy",
     36: "History", 
     37: "Western",     
     53: "Thriller",
     80: "Crime",  
     99: "Documentary",
     878: "Science Fiction", 
     9648: "Mystery",    
     10402: "Music",     
     10749: "Romance",     
     10751: "Family",    
     10752: "War",     
     10769: "Foreign", 
     10770: "TV Movie", }

# %%
# need to extract labels(genres) of each poster now and insert into Ydata
# and also process each poster into numpy arrays and insert into Xdata

import os

dir = './Movie-Genre-Prediction/en_90/'
dir2= './Movie-Genre-Prediction/images/'

labels = []

x_data = []
y_data = []

poster_shape = (268,182,3)

for i,row in df2.iterrows():
  
  row_genre = { genre['id'] for genre in eval(row['genres']) if genre['id'] in genres_dict }
  image_loc = dir + str(row['imdb_id']) + '.jpg'
  image_loc2= dir2 + str(row['imdb_id']) + '.jpg'
  
  if os.path.exists(image_loc):
    
    poster = cv2.imread(image_loc)
    if poster.shape == poster_shape:
      x_data.append(poster)
      y_data.append(row_genre)
  
  elif os.path.exists(image_loc2):
    
    poster = cv2.imread(image_loc2)
    if poster.shape == poster_shape:
      x_data.append(poster)
      y_data.append(row_genre)

# %%
len(x_data)
# Out:
# 18938

# %%
# !pip install scikit-multilearn
# Out:
# Collecting scikit-multilearn
#   Downloading scikit_multilearn-0.2.0-py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 2.8 MB/s
# Installing collected packages: scikit-multilearn
# Successfully installed scikit-multilearn-0.2.0

# %%
from sklearn.preprocessing import MultiLabelBinarizer 
from skmultilearn.model_selection import iterative_train_test_split
import cv2
genre_list = list(genres_dict.keys())

mlb = MultiLabelBinarizer(classes=genre_list)
Y_data = mlb.fit_transform(y_data)

X_data = np.array(x_data)
X_data = np.array(list(map(lambda x: cv2.resize(x, (224,224), interpolation=cv2.INTER_AREA), X_data)))

# %%
X_train, Y_train, X_test, Y_test = iterative_train_test_split(X_data, Y_data, test_size = 0.33)
del X_data
del Y_data
del x_data
del df2

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 12619
# 6319

# %%
import tensorflow
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras import Model

model1 = VGG19(weights='imagenet', include_top=False)
model1.summary()
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Concatenate, Flatten, Dense, Reshape

input1 = tf.keras.Input(shape = (224,224,3))    # movie poster

layer = Conv2D( filters=32, kernel_size=7, strides=2, padding="same", use_bias=True, input_shape=poster_shape, activation='relu')(input1)
#layer = MaxPooling2D( pool_size=2, strides=2 )(layer)

layer = Conv2D( filters=32, kernel_size=5, strides=2, padding="same", use_bias=True, activation='relu')(layer)     
#layer = MaxPooling2D(pool_size=2, strides=1)(layer)
layer = Dropout(0.3)(layer)
    
layer = Conv2D( filters=64, kernel_size=5, strides=1, padding="same", use_bias=True, activation='relu')(layer)
layer = MaxPooling2D(pool_size=2, strides=2)(layer)
layer = Dropout(0.3)(layer)
        
layer = Conv2D( filters=64, kernel_size=3, strides=1, padding="same", use_bias=True, activation='relu')(layer) 
layer = MaxPooling2D(pool_size=2, strides=2)(layer)   
layer = Dropout(0.3)(layer)
    
layer = Conv2D( filters=64, kernel_size=3, strides=2, padding="same", use_bias=True, activation='relu')(layer)
layer = MaxPooling2D(pool_size=2, strides=2)(layer)
layer = Dropout(0.3)(layer)
    
layer = Conv2D( filters=64, kernel_size=3, strides=2, padding="same", use_bias=True, activation='relu')(layer)
layer = MaxPooling2D(pool_size=2, strides=2)(layer)
layer = Dropout(0.3)(layer)

layer =  Flatten(name='flatten_last')(layer)

out1 =  Dense(4096 , activation = 'relu')(layer)

# %%
input2 = tf.keras.Input(shape=( 7, 7, 512))       # output from vgg19
input_fl = Flatten(name='Flatten_VGG19_output')(input2)
out2 = Dense(4096, activation='relu')(input_fl)

print(out2.shape)

# input1, out1 corresponds to cnn model
# input2, out2 corresponds to VGG19

mergedOut = tf.keras.layers.Concatenate(axis=-1)([out2, out1])
print(mergedOut.shape)

mergedOut = Dense(1024, activation='relu')(mergedOut)
mergedOut = Dropout(0.4)(mergedOut)
mergedOut = Dense(256, activation='relu')(mergedOut)
mergedOut = Dropout(0.4)(mergedOut)

# output layer
mergedOut = Dense(20, activation='sigmoid')(mergedOut)
# Out:
# (?, 4096)
# (?, 8192)

# %%
from tensorflow.keras import Model

newModel = Model(inputs=[input2, input1], outputs=[mergedOut])

# %%
newModel.compile(optimizer='adam', loss='binary_crossentropy', metrics=['categorical_accuracy']) 

newModel.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 32) 4736        input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 32)   25632       conv2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 56, 56, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 64)   51264       dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 28, 28, 64)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 28, 28, 64)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 64)   36928       dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 14, 14, 64)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 7, 7, 64)     36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 3, 3, 64)     0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 3, 3, 64)     0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 2, 2, 64)     36928       dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 1, 1, 64)     0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 7, 7, 512)]  0
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1, 1, 64)     0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# Flatten_VGG19_output (Flatten)  (None, 25088)        0           input_7[0][0]
# __________________________________________________________________________________________________
# flatten_last (Flatten)          (None, 64)           0           dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 4096)         102764544   Flatten_VGG19_output[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 4096)         266240      flatten_last[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 8192)         0           dense_10[0][0]
#                                                                  dense[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1024)         8389632     concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 1024)         0           dense_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 256)          262400      dropout_9[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 256)          0           dense_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 20)           5140        dropout_10[0][0]
# ==================================================================================================
# Total params: 111,880,372
# Trainable params: 111,880,372
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras import backend as K

print(X_train[0].shape)

out = model1.predict( preprocess_input(X_train) )
print(out.shape)
# Out:
# (224, 224, 3)
# (12619, 7, 7, 512)

# %%
history = newModel.fit([ out, preprocess_input(X_train)], Y_train, batch_size=16, epochs=20, verbose=1)
plt.plot(history.history['categorical_accuracy'])
# Out:
# Train on 12619 samples
# Epoch 1/20
# 12619/12619 [==============================] - 253s 20ms/sample - loss: 0.4811 - categorical_accuracy: 0.2084
# Epoch 2/20
# 12619/12619 [==============================] - 254s 20ms/sample - loss: 0.3006 - categorical_accuracy: 0.2766
# Epoch 3/20
# 12619/12619 [==============================] - 254s 20ms/sample - loss: 0.2845 - categorical_accuracy: 0.2988
# Epoch 4/20
# 12619/12619 [==============================] - 258s 20ms/sample - loss: 0.2691 - categorical_accuracy: 0.3254
# Epoch 5/20
# 12619/12619 [==============================] - 260s 21ms/sample - loss: 0.2561 - categorical_accuracy: 0.3477
# Epoch 6/20
# 12619/12619 [==============================] - 264s 21ms/sample - loss: 0.2423 - categorical_accuracy: 0.3839
# Epoch 7/20
# 12619/12619 [==============================] - 257s 20ms/sample - loss: 0.2297 - categorical_accuracy: 0.4056
# Epoch 8/20
# 12619/12619 [==============================] - 257s 20ms/sample - loss: 0.2233 - categorical_accuracy: 0.4244
# Epoch 9/20
# 12619/12619 [==============================] - 254s 20ms/sample - loss: 0.2195 - categorical_accuracy: 0.4315
# Epoch 10/20
# 12619/12619 [==============================] - 249s 20ms/sample - loss: 0.2133 - categorical_accuracy: 0.4435
# Epoch 11/20
# 12619/12619 [==============================] - 250s 20ms/sample - loss: 0.2089 - categorical_accuracy: 0.4515
# Epoch 12/20
# 12619/12619 [==============================] - 253s 20ms/sample - loss: 0.2060 - categorical_accuracy: 0.4505
# Epoch 13/20
# 12619/12619 [==============================] - 252s 20ms/sample - loss: 0.2041 - categorical_accuracy: 0.4538
# Epoch 14/20
# 12619/12619 [==============================] - 253s 20ms/sample - loss: 0.2029 - categorical_accuracy: 0.4555
# Epoch 15/20
# 12619/12619 [==============================] - 252s 20ms/sample - loss: 0.2015 - categorical_accuracy: 0.4633
# Epoch 16/20
# 12619/12619 [==============================] - 258s 20ms/sample - loss: 0.1992 - categorical_accuracy: 0.4552
# Epoch 17/20
# 12619/12619 [==============================] - 287s 23ms/sample - loss: 0.1969 - categorical_accuracy: 0.4553
# Epoch 18/20
# 12619/12619 [==============================] - 270s 21ms/sample - loss: 0.1960 - categorical_accuracy: 0.4649
# Epoch 19/20
# 12619/12619 [==============================] - 258s 20ms/sample - loss: 0.1946 - categorical_accuracy: 0.4676
# Epoch 20/20
# 12619/12619 [==============================] - 269s 21ms/sample - loss: 0.1947 - categorical_accuracy: 0.4598

# %%
newModel.save('cnn_vgg19.h5')

# %%
# implementing subset accuracy

def accuracy_metric( y_pred, y_data ):
  
  # y_pred is list of list of floats, while y_data is one hot encoded genres
  accuracy = 0
  
  for i in range(len(y_pred)):
    
    pred_genres = y_pred[i].argsort()[-3:]                   # will return indices of top 3 predictions
    z_pred = np.zeros(len(genres_dict))
    z_pred[pred_genres[0]] =  1
    z_pred[pred_genres[1]] =  1
    z_pred[pred_genres[2]] =  1
    
    num = np.dot(z_pred, y_data[i])
    denum = np.logical_or(z_pred, y_data[i]).sum()
    accuracy += num / denum
    
  return accuracy / len(y_pred)

# %%
def accuracy_2(y_true, y_pred):
  # (y_pred intersection y_true)/(y_pred union y_true)
  accuracy = 0
  for i in range(len(y_pred)):
    pred = np.rint(y_pred[i])
    numerator = np.sum(pred * y_true[i])
    denominator = np.logical_or(pred, y_true[i]).sum()
    accuracy += numerator / denominator
    
  return accuracy / len(y_pred)

# %%
# now we need to see subset accuracy on test data

X_test = preprocess_input(X_test)
out2 =  model1.predict(X_test)
print(out2.shape)
features = newModel.predict([out2, X_test])
print(accuracy_2(Y_test, features))
print(accuracy_metric(features, Y_test))
# Out:
# (6319, 7, 7, 512)
# 0.23729681459543764
# 0.2961414554744161

# %%
print(features.shape)
# Out:
# (6319, 20)

# %%
# function to print poster with its true and predicted values

import random
from PIL import Image
from matplotlib.pyplot import imshow

% matplotlib inline

def test_sample(sample):
  
  plt.imshow(X_test[sample])
  
  genre_ind = list(genres_dict.keys())

  print('True Values :') 

  count = np.sum(Y_test[sample])
  true_genres = Y_test[sample].argsort()[-count:]
  l = []
  for j in range(count):
    l.append(genres_dict[genre_ind[true_genres[j]]])
  l.sort()
  print(l)
  
  print('Predicted Values')     
  prediction = features[sample] 
  pred_genres = prediction.argsort()[-3:]                   # will return indices of top 3 predictions
  
  
  l=[]
  l.append(genres_dict[genre_ind[pred_genres[0]]])
  l.append(genres_dict[genre_ind[pred_genres[1]]])
  l.append(genres_dict[genre_ind[pred_genres[2]]])
  l.sort()
  print(l)
  
  print('-' * 40)

# %%
test_sample(40)
# Out:
# True Values :
# ['Comedy', 'Mystery', 'Romance', 'Thriller']
# Predicted Values
# ['Comedy', 'Drama', 'Romance']
# ----------------------------------------

# %%
test_sample(20)
# Out:
# True Values :
# ['Action', 'Crime', 'Horror', 'Science Fiction', 'Thriller']
# Predicted Values
# ['Action', 'Comedy', 'Drama']
# ----------------------------------------

# %%
test_sample(150)
# Out:
# True Values :
# ['Action', 'Horror', 'Thriller']
# Predicted Values
# ['Action', 'Science Fiction', 'Thriller']
# ----------------------------------------

# %%
test_sample(200)
# Out:
# True Values :
# ['Comedy', 'Crime', 'Drama', 'Foreign']
# Predicted Values
# ['Comedy', 'Drama', 'Romance']
# ----------------------------------------

# %%
test_sample(1000)
# Out:
# True Values :
# ['Comedy']
# Predicted Values
# ['Comedy', 'Drama', 'Romance']
# ----------------------------------------
